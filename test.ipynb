# %%
print(id(200)) #identita
print(type(200)) #datový typ
print(200) #hodnota
print(id(1000))
print(id(1000))
# /  výsledek je vždy float
# + - * výsledek může být int
# // celočíselné dělení (bezezbytku) - výsledek je typ podle vstupu
# % modulo = zůstatek po celočíselném dělení
# ** mocnina
# == porovnání hodnot
# decimal (import decimal) se píše do uvozovek - decimal.decimal("10.7")
# round - zaokrouhlení round(0.3 + 0.1, 3) - 0,3+0,1 zaokrouhleno na tři desetinná místa
# pořadí vyhodnocování operátorů (); **; *; /; +; -
# "''" '' ""
# \n udělá nový řádek    Alt + Q = \
# """ tři uvozovky před text a pak za = že lze text rozdělit na více řádků
# "2" + "2" = 22 (sčítání stringů)
print("Ondřej" [3]) #třetí prvek to vytiskne (3)
print("Ondřej" [-1]) #poslední prvek to vytiskne
print("Ondřej Laskafeld" [3:8]) #tisk 3-7 symbolu, 8 už ne...
print("Ondřej Laskafeld" [:8]) #tisk od 0 do 7 včetně
print("Ondřej Laskafeld" [3:]) #tisk od 3 do posledního symbolu

print("123456789" [::1]) #123456789
print("123456789" [::2]) #13579
print("123456789" [::3]) #147
print("123456789" [::50]) #1

print("Ondřej Laskafeld" [3:8:2]) #řj - od 3 do 8, každý druhý

jmeno1 = "Ondřej"
jmeno2 = "Ondřej"
jmeno3 = "Ondřej" 
print(id(jmeno1), id(jmeno2), id(jmeno3)) # =jiné id

jmeno1 = "Ondrej"
jmeno2 = "Ondrej"
jmeno3 = "Ondrej" 
print(id(jmeno1), id(jmeno2), id(jmeno3)) # =stejné id

list = ["Marek", "Matouš", "Lukáš", "Jan", "Pavel", 1, 2, 3, 4.0, 5.55] #tvorba seznamů
print(list)

from sys import getsizeof

print(getsizeof(1))
print(getsizeof(10000))
print(getsizeof(1*2))
#vše stejné protože jsou to seznamy se stejným počtem prvků
print(getsizeof([5, 6, 7, 8])) # víc prvků = jiná velikost

l1 = [1, 2, 3]
l2 = l1
print(l1, l2) 
l2[0] = -1 #změní první prvek v seznamu l2 i l1
print(l1, l2)
# Out:
# 140735905018520
# <class 'int'>
# 200
# 2609065865136
# 2609065864112
# ř
# j
# řej L
# Ondřej L
# řej Laskafeld
# 123456789
# 13579
# 147
# 1
# řjL
# 2609066525200 2609066533440 2609066529920
# 2609060646896 2609060646896 2609060646896
# ['Marek', 'Matouš', 'Lukáš', 'Jan', 'Pavel', 1, 2, 3, 4.0, 5.55]
# 28
# 28
# 28
# 88
# [1, 2, 3] [1, 2, 3]
# [-1, 2, 3] [-1, 2, 3]
